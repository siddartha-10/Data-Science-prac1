# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('health_data.xlsx')

# %%
df.head()
# Out:
#    ID  Diabetes_012  HighBP  HighChol  CholCheck  BMI  DiffWalk  Sex  Age
# 0   1             0       1         0          1   26         0    1    4  \
# 1   2             0       1         1          1   26         0    1   12
# 2   4             0       1         1          1   28         0    1   11
# 3   5             0       0         0          1   29         0    0    8
# 4   6             0       0         0          1   18         0    0    1
#
#    Education  ...  PhysActivity  Fruits  Smoker  Veggies  HvyAlcoholConsump
# 0          6  ...             1       0       0        1                  0  \
# 1          6  ...             0       1       1        0                  0
# 2          6  ...             1       1       1        1                  0
# 3          5  ...             1       1       1        1                  0
# 4          4  ...             1       1       0        1                  0
#
#    AnyHealthcare  NoDocbcCost  GenHlth  MentHlth  PhysHlth
# ...

# %%
df.describe()
# Out:
#                  ID  Diabetes_012        HighBP      HighChol     CholCheck
# count  69397.000000  69397.000000  69397.000000  69397.000000  69397.000000  \
# mean   35339.021154      0.500079      0.563771      0.526103      0.975258
# std    20399.389229      0.500004      0.495920      0.499322      0.155338
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%    17661.000000      0.000000      0.000000      0.000000      1.000000
# 50%    35352.000000      1.000000      1.000000      1.000000      1.000000
# 75%    52992.000000      1.000000      1.000000      1.000000      1.000000
# max    70692.000000      1.000000      1.000000      1.000000      1.000000
#
#                 BMI      DiffWalk           Sex           Age     Education
# count  69397.000000  69397.000000  69397.000000  69397.000000  69397.000000  \
# mean      29.859173      0.252605      0.456792      8.586106      4.920501
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Diabetes_012', 'HighBP', 'HighChol', 'CholCheck', 'BMI',
#        'DiffWalk', 'Sex', 'Age', 'Education', 'Income', 'Stroke',
#        'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Smoker', 'Veggies',
#        'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth',
#        'MentHlth', 'PhysHlth'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                      int64
# Diabetes_012            int64
# HighBP                  int64
# HighChol                int64
# CholCheck               int64
# BMI                     int64
# DiffWalk                int64
# Sex                     int64
# Age                     int64
# Education               int64
# Income                  int64
# Stroke                  int64
# HeartDiseaseorAttack    int64
# PhysActivity            int64
# Fruits                  int64
# Smoker                  int64
# Veggies                 int64
# HvyAlcoholConsump       int64
# AnyHealthcare           int64
# NoDocbcCost             int64
# GenHlth                 int64
# MentHlth                int64
# PhysHlth                int64
# dtype: object

# %% [markdown]
# ## bmi below 18.5 is underweight 18.5 - 24.5 normal 25+ overweight

# %%
catergories = ['underweight','normal','overweight']
def bmi(num):
    if(num < 18.5):
        return 'underweight'
    if(num >= 25):
        return 'overweight'
    if(num > 18.5 and num < 24.5):
        return 'normal'
df['bmi_categories'] = df['BMI'].apply(bmi)

# %%
df.tail()
# Out:
#           ID  Diabetes_012  HighBP  HighChol  CholCheck  BMI  DiffWalk  Sex
# 69392  70688             1       0         1          1   37         0    0  \
# 69393  70689             1       0         1          1   29         1    1
# 69394  70690             1       1         1          1   25         1    0
# 69395  70691             1       1         1          1   18         1    0
# 69396  70692             1       1         1          1   25         0    0
#
#        Age  Education  ...  Fruits  Smoker  Veggies  HvyAlcoholConsump
# 69392    6          4  ...       0       0        1                  0  \
# 69393   10          3  ...       1       1        1                  0
# 69394   13          6  ...       1       0        0                  0
# 69395   11          2  ...       0       0        0                  0
# 69396    9          6  ...       1       0        0                  0
#
#        AnyHealthcare  NoDocbcCost  GenHlth  MentHlth  PhysHlth  bmi_categories
# ...

# %%
df.describe()
# Out:
#                  ID  Diabetes_012        HighBP      HighChol     CholCheck
# count  69397.000000  69397.000000  69397.000000  69397.000000  69397.000000  \
# mean   35339.021154      0.500079      0.563771      0.526103      0.975258
# std    20399.389229      0.500004      0.495920      0.499322      0.155338
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%    17661.000000      0.000000      0.000000      0.000000      1.000000
# 50%    35352.000000      1.000000      1.000000      1.000000      1.000000
# 75%    52992.000000      1.000000      1.000000      1.000000      1.000000
# max    70692.000000      1.000000      1.000000      1.000000      1.000000
#
#                 BMI      DiffWalk           Sex           Age     Education
# count  69397.000000  69397.000000  69397.000000  69397.000000  69397.000000  \
# mean      29.859173      0.252605      0.456792      8.586106      4.920501
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69397 entries, 0 to 69396
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    69397 non-null  int64
#  1   Diabetes_012          69397 non-null  int64
#  2   HighBP                69397 non-null  int64
#  3   HighChol              69397 non-null  int64
#  4   CholCheck             69397 non-null  int64
#  5   BMI                   69397 non-null  int64
#  6   DiffWalk              69397 non-null  int64
#  7   Sex                   69397 non-null  int64
#  8   Age                   69397 non-null  int64
#  9   Education             69397 non-null  int64
#  10  Income                69397 non-null  int64
#  11  Stroke                69397 non-null  int64
#  12  HeartDiseaseorAttack  69397 non-null  int64
#  13  PhysActivity          69397 non-null  int64
#  14  Fruits                69397 non-null  int64
# ...

# %% [markdown]
# ## Calculate average mental score (MentHlth) of subjects in each category of BMI (underweight, normal, overweight) (using for loop)!

# %%
df.groupby('bmi_categories')['MentHlth'].mean()
# Out:
# bmi_categories
# normal         3.069905
# overweight     3.908526
# underweight    5.242188
# Name: MentHlth, dtype: float64

# %% [markdown]
# ## Find average physical health score (PhysHlth) of subjects in smokers’ groups!

# %%
def smoker(num):
    if(num==0):
        return 'non-smoker'
    else:
        return 'smoker'
df['smokers_categories'] = df['Smoker'].apply(smoker)

# %%
df.head()
# Out:
#    ID  Diabetes_012  HighBP  HighChol  CholCheck  BMI  DiffWalk  Sex  Age
# 0   1             0       1         0          1   26         0    1    4  \
# 1   2             0       1         1          1   26         0    1   12
# 2   4             0       1         1          1   28         0    1   11
# 3   5             0       0         0          1   29         0    0    8
# 4   6             0       0         0          1   18         0    0    1
#
#    Education  ...  Smoker  Veggies  HvyAlcoholConsump  AnyHealthcare
# 0          6  ...       0        1                  0              1  \
# 1          6  ...       1        0                  0              1
# 2          6  ...       1        1                  0              1
# 3          5  ...       1        1                  0              1
# 4          4  ...       0        1                  0              0
#
#    NoDocbcCost  GenHlth  MentHlth  PhysHlth  bmi_categories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69397 entries, 0 to 69396
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    69397 non-null  int64
#  1   Diabetes_012          69397 non-null  int64
#  2   HighBP                69397 non-null  int64
#  3   HighChol              69397 non-null  int64
#  4   CholCheck             69397 non-null  int64
#  5   BMI                   69397 non-null  int64
#  6   DiffWalk              69397 non-null  int64
#  7   Sex                   69397 non-null  int64
#  8   Age                   69397 non-null  int64
#  9   Education             69397 non-null  int64
#  10  Income                69397 non-null  int64
#  11  Stroke                69397 non-null  int64
#  12  HeartDiseaseorAttack  69397 non-null  int64
#  13  PhysActivity          69397 non-null  int64
#  14  Fruits                69397 non-null  int64
# ...

# %%
df.groupby('smokers_categories')['PhysHlth'].mean()
# Out:
# smokers_categories
# non-smoker    4.658250
# smoker        7.078571
# Name: PhysHlth, dtype: float64

# %%
df.describe()
# Out:
#                  ID  Diabetes_012        HighBP      HighChol     CholCheck
# count  69397.000000  69397.000000  69397.000000  69397.000000  69397.000000  \
# mean   35339.021154      0.500079      0.563771      0.526103      0.975258
# std    20399.389229      0.500004      0.495920      0.499322      0.155338
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%    17661.000000      0.000000      0.000000      0.000000      1.000000
# 50%    35352.000000      1.000000      1.000000      1.000000      1.000000
# 75%    52992.000000      1.000000      1.000000      1.000000      1.000000
# max    70692.000000      1.000000      1.000000      1.000000      1.000000
#
#                 BMI      DiffWalk           Sex           Age     Education
# count  69397.000000  69397.000000  69397.000000  69397.000000  69397.000000  \
# mean      29.859173      0.252605      0.456792      8.586106      4.920501
# ...

# %% [markdown]
# ## Compute max mental health score (MentHlth) in different categories of education level!

# %%
def school(num):
    if(num==1):
        return 'kindergarten'
    if(num==2):
        return 'elementary'
    if(num==3):
        return 'high school'
    if(num==4):
        return 'high school grad'
    if(num==5):
        return 'college'
    if(num==6):
        return 'college graduate'
df['education_category'] = df['Education'].apply(school)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69397 entries, 0 to 69396
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    69397 non-null  int64
#  1   Diabetes_012          69397 non-null  int64
#  2   HighBP                69397 non-null  int64
#  3   HighChol              69397 non-null  int64
#  4   CholCheck             69397 non-null  int64
#  5   BMI                   69397 non-null  int64
#  6   DiffWalk              69397 non-null  int64
#  7   Sex                   69397 non-null  int64
#  8   Age                   69397 non-null  int64
#  9   Education             69397 non-null  int64
#  10  Income                69397 non-null  int64
#  11  Stroke                69397 non-null  int64
#  12  HeartDiseaseorAttack  69397 non-null  int64
#  13  PhysActivity          69397 non-null  int64
#  14  Fruits                69397 non-null  int64
# ...

# %%
df.head()
# Out:
#    ID  Diabetes_012  HighBP  HighChol  CholCheck  BMI  DiffWalk  Sex  Age
# 0   1             0       1         0          1   26         0    1    4  \
# 1   2             0       1         1          1   26         0    1   12
# 2   4             0       1         1          1   28         0    1   11
# 3   5             0       0         0          1   29         0    0    8
# 4   6             0       0         0          1   18         0    0    1
#
#    Education  ...  Veggies  HvyAlcoholConsump  AnyHealthcare  NoDocbcCost
# 0          6  ...        1                  0              1            0  \
# 1          6  ...        0                  0              1            0
# 2          6  ...        1                  0              1            0
# 3          5  ...        1                  0              1            0
# 4          4  ...        1                  0              0            0
#
#    GenHlth  MentHlth  PhysHlth  bmi_categories  smokers_categories
# ...

# %%
df.groupby('education_category')['MentHlth'].max()
# Out:
# education_category
# college             30
# college graduate    30
# elementary          30
# high school         30
# high school grad    30
# kindergarten        30
# Name: MentHlth, dtype: int64

# %%
df.groupby('education_category')['MentHlth'].mean()
# Out:
# education_category
# college             4.099853
# college graduate    2.696508
# elementary          5.976961
# high school         6.004132
# high school grad    4.196070
# kindergarten        6.706667
# Name: MentHlth, dtype: float64

# %% [markdown]
# ## Here what i am trying to do is getting the infromation about the object type variables form the dataframe

# %%
df.describe(include='O')
## this is one way to do it
# Out:
#        bmi_categories smokers_categories education_category
# count           69397              69397              69397
# unique              3                  2                  6
# top        overweight         non-smoker   college graduate
# freq            54595              36395              25513

# %%
a = df.dtypes[df.dtypes=='object'].index
## here i am trying to gather all the index whose type is object

# %%
df[a].describe()
## here i am describing all the object type index or columns
# Out:
#        bmi_categories smokers_categories education_category
# count           69397              69397              69397
# unique              3                  2                  6
# top        overweight         non-smoker   college graduate
# freq            54595              36395              25513

# %% [markdown]
# ## alocoholic vs mental health

# %%
def alco(num):
    if(num==0):
        return "non alcoholic"
    if(num==1):
        return "alcoholic"
df['alcoholic_category'] = df['HvyAlcoholConsump'].apply(alco)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69397 entries, 0 to 69396
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    69397 non-null  int64
#  1   Diabetes_012          69397 non-null  int64
#  2   HighBP                69397 non-null  int64
#  3   HighChol              69397 non-null  int64
#  4   CholCheck             69397 non-null  int64
#  5   BMI                   69397 non-null  int64
#  6   DiffWalk              69397 non-null  int64
#  7   Sex                   69397 non-null  int64
#  8   Age                   69397 non-null  int64
#  9   Education             69397 non-null  int64
#  10  Income                69397 non-null  int64
#  11  Stroke                69397 non-null  int64
#  12  HeartDiseaseorAttack  69397 non-null  int64
#  13  PhysActivity          69397 non-null  int64
#  14  Fruits                69397 non-null  int64
# ...

# %%
df.groupby(['bmi_categories','alcoholic_category'])['MentHlth'].mean()
# Out:
# bmi_categories  alcoholic_category
# normal          alcoholic             4.120968
#                 non alcoholic         3.001279
# overweight      alcoholic             4.467868
#                 non alcoholic         3.886660
# underweight     alcoholic             4.844444
#                 non alcoholic         5.272269
# Name: MentHlth, dtype: float64

# %%
df.groupby('alcoholic_category')['Stroke'].count()
# Out:
# alcoholic_category
# alcoholic         2967
# non alcoholic    66430
# Name: Stroke, dtype: int64
